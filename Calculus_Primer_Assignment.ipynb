# %% [markdown]
# <a href="https://colab.research.google.com/github/tailorfenil/BigDataLab_InteractiveScatterPlot_D3/blob/master/Calculus_Primer_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imagine a building that uses a complex energy consumption system to regulate its temperature and lighting. The energy consumption system has several variables that affect its efficiency, such as the temperature setpoint, lighting levels, and ventilation rates. The function J(x) = x2 - 4x + 3 can be seen as a simplified model of the efficiency of the energy consumption system, where x represents one of the variables that affect the system's efficiency. For example, x could represent the temperature setpoint. By adjusting the value of x using Gradient Descent, the building managers can find the optimal temperature setpoint that would minimize the value of the cost function and result in the most efficient energy consumption system. This optimization would result in lower energy consumption costs and reduced carbon emissions, while still maintaining a comfortable environment for the building occupants. You will be implementing the Gradient Descent algorithm to find the minimum of the quadratic cost function.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return x**2 - 4*x + 3

line= np.linspace(-20,20,7000)

# Evaluate f(x) for each value of x
y = f(line)

# Plot f(x) versus x
plt.plot(line, y)

# Add labels and a title to the plot
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x) versus x')
plt.grid(True)

# Display the plot
plt.show()

# %%
import sympy as sp


# Define the gradient of the cost function
def gradient(x):
  return 2*x - 4

def threshould_no_of_iteration(max_iterations,cost_values,x,learning_rate=0.1):
  # Iterate until convergence or max iterations
  start_time= time.time()
  for i in range(max_iterations):
      # Calculate the cost and gradient at the current parameter
      cost = f(x)
      grad = gradient(x)

      # Update the parameter
      x = x - learning_rate * grad

      # Store the cost value
      cost_values.append(cost)

      # # Print the progress
      # if i % 10 == 0:
      #     print("Iteration {}: x = {}, cost = {},grad ={}".format(i, x, cost,grad))
  end_time= time.time()
  duration=end_time-start_time
  print(f'duration {duration}')

# Initialize the model parameter with a random value
# x = np.random.randn()
# Define the start and end range for initializing x
start_range = -5
end_range = 5

# Initialize x with a random value within the specified range
x = np.random.uniform(start_range, end_range)

# # Set the learning rate
# learning_rate = 0.1

# Set the maximum number of iterations
max_iterations = 100

######## With different leaning rate##############
'''
lr =[0.1*i for i in range(1,10)]
# print(lr)
for i in lr:
  cost_values = []
  threshould_no_of_iteration(max_iterations,cost_values,x,i)
  plt.plot(cost_values)
  plt.xlabel("Iterations")
  plt.ylabel("Cost")
  plt.show()
  print(cost_values[-1])
'''

######## With constant leaning rate##############
'''
cost_values = []
threshould_no_of_iteration(max_iterations,cost_values,x)
print(cost_values[-1])
plt.plot(cost_values)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.show()
print(cost_values[-1])
'''
# Out:
# duration 0.00010585784912109375
# -1.0
# duration 0.0004036426544189453
# -1.0
# duration 0.00012350082397460938
# -1.0
# duration 0.00012755393981933594
# -1.0
# duration 7.724761962890625e-05
# -1.0
# duration 0.0001316070556640625
# -1.0
# duration 0.00011944770812988281
# -1.0
# duration 0.00015163421630859375
# -1.0
# duration 0.00014972686767578125
# -1.0
# '\ncost_values = []\nthreshould_no_of_iteration(max_iterations,cost_values,x)\nprint(cost_values[-1])\nplt.plot(cost_values)\nplt.xlabel("Iterations")\nplt.ylabel("Cost")\nplt.show()\nprint(cost_values[-1])\n'

# %%
# using bisection search
import numpy as np
import matplotlib.pyplot as plt
import time

def f(x):
    return x**2 - 4*x + 3

def gradient(x):
    return 2*x - 4

# Set the convergence threshold for interval size
convergence_threshold = 1e-9

cost=[]

def binary_search(low,high):

  start_time= time.time()

  while (high-low) > convergence_threshold:

    mid= low+(high-low)/2
    cost.append(f(mid))

    if gradient(mid)>0:
      high=mid
    else:
      low=mid

  end_time= time.time()
  elapsed_time = end_time-start_time
  return (low,high,elapsed_time)

optimized_x,optimized_y,elapsed_time = binary_search(-5,5)
print(optimized_x)
print(optimized_y)
print((optimized_x+optimized_y)/2)
print(f((optimized_x+optimized_y)/2))
print(elapsed_time)

plt.plot(cost)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# 1.9999999995343387
# 2.0000000001164153
# 1.999999999825377
# -1.0
# 5.626678466796875e-05

# %%
x=5

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**2 - 4*x + 3

def gradient(x):
    return 2*x - 4

# x = np.random.uniform(-5, 5)  # Start with a random value within the range


learning_rate = 0.5
max_iterations = 100
convergence_threshold = 1e-9

cost_values = []
x=6
print(x)

for i in range(max_iterations):
    cost = f(x)
    grad = gradient(x)

    # Check if the gradient changes sign (overshooting)
    print(prev_grad)
    print(grad)
    if i > 0 and np.sign(grad) != np.sign(prev_grad):
        print('changed ')
        learning_rate /= 5  # Reduce the learning rate

    x = x - learning_rate * grad
    prev_grad = grad

    cost_values.append(cost)

    print("Iteration {}: x = {}, cost = {}, grad = {}, learning_rate = {}".format(i, x, cost, grad, learning_rate))

    if abs(grad) < convergence_threshold:
        break

plt.plot(cost_values)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# 6
# 0.0
# 8
# Iteration 0: x = 2.0, cost = 15, grad = 8, learning_rate = 0.5
# 8
# 0.0
# changed
# Iteration 1: x = 2.0, cost = -1.0, grad = 0.0, learning_rate = 0.1
